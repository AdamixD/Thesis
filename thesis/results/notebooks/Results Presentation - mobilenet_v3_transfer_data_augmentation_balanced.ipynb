# %% [markdown]
# ## Results Presentation - mobilenet_v3_transfer_data_augmentation_balanced

# %%
from results_analyzer import ResultsAnalyzer

# %%
RESULTS_FILE_PATH = "/Users/adamdabkowski/DataspellProjects/Thesis/thesis/results/txt/mobilenet_v3_transfer_data_augmentation_balanced_output.txt"
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
FIGURE_SIZE = (14, 5)

# %%
results_analyzer = ResultsAnalyzer(
    results_file_path=RESULTS_FILE_PATH,
    categories=CATEGORIES,
    figure_size=FIGURE_SIZE
)

# %%
results_analyzer.df
# Out:
#       loss  accuracy  categorical_accuracy  precision  precision_angry  \
# 0   1.4987    0.4320                0.4320     0.6819           0.5208
# 1   1.2626    0.5249                0.5249     0.7136           0.6432
# 2   1.1873    0.5530                0.5530     0.7203           0.6556
# 3   1.1314    0.5682                0.5682     0.7244           0.6473
# 4   1.0825    0.5887                0.5887     0.7369           0.6722
# 5   1.0462    0.6024                0.6024     0.7400           0.6857
# 6   1.0086    0.6141                0.6141     0.7478           0.7141
# 7   0.9840    0.6210                0.6210     0.7472           0.7029
# 8   0.9620    0.6292                0.6292     0.7510           0.7075
# 9   0.9240    0.6397                0.6397     0.7581           0.7194
# 10  0.9167    0.6416                0.6416     0.7589           0.7104
# 11  0.8879    0.6531                0.6531     0.7667           0.7219
# ...

# %%
results_analyzer.display_average_epoch_training_time()
# Out:
# 17 min 47 s

# %%
results_analyzer.display_total_training_time()
# Out:
# 10 h 39 min 59 s

# %%
results_analyzer.display_results()
# Out:
# loss                           0.542400
# accuracy                       0.773100
# categorical_accuracy           0.773100
# precision                      0.835700
# precision_angry                0.811400
# precision_disgust              0.831900
# precision_fear                 0.784000
# precision_happy                0.940200
# precision_neutral              0.779400
# precision_sad                  0.763400
# precision_surprise             0.846400
# recall                         0.709300
# recall_angry                   0.663500
# recall_disgust                 0.982100
# recall_fear                    0.530500
# recall_happy                   0.860500
# recall_neutral                 0.670000
# recall_sad                     0.569600
# recall_surprise                0.871000
# val_loss                       0.950000
# val_accuracy                   0.668000
# val_categorical_accuracy       0.668000
# val_precision                  0.735200
# ...

# %%
results_analyzer.plot_metric_comparison(metric="loss")

# %%
results_analyzer.plot_metric_comparison(metric="accuracy")

# %%
results_analyzer.plot_metric_comparison(metric="precision")

# %%
results_analyzer.plot_metric_comparison(metric="recall")

# %%
results_analyzer.plot_metric_comparison(metric="f1_score")

# %%
results_analyzer.plot_categories_metric_comparison(
    metric="f1_score",
    dataset_type="training",
    color_palette="tab10"
)

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(
    metric="f1_score",
    dataset_type="validation",
    color_palette="tab10",
)

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="validation")

# %%
f1_score_test = ResultsAnalyzer.calculate_f1_score(
    precision=0.7963,
    recall=0.7858,
)
print(round(float(f1_score_test), 5))
# Out:
# 0.79102

# %%
STANDARD_RESULTS_FILE_PATH = "/Users/adamdabkowski/DataspellProjects/Thesis/thesis/results/txt/mobilenet_v3_transfer_data_augmentation_output.txt"
BALANCED_RESULTS_FILE_PATH = "/Users/adamdabkowski/DataspellProjects/Thesis/thesis/results/txt/mobilenet_v3_transfer_data_augmentation_balanced_output.txt"

# %%
results_analyzer_standard = ResultsAnalyzer(
    results_file_path=STANDARD_RESULTS_FILE_PATH,
    categories=CATEGORIES,
    figure_size=FIGURE_SIZE
)

results_analyzer_balanced = ResultsAnalyzer(
    results_file_path=BALANCED_RESULTS_FILE_PATH,
    categories=CATEGORIES,
    figure_size=FIGURE_SIZE
)

# %%
validation_f1_score = ResultsAnalyzer.concat_statistic_data(
    standard_data=results_analyzer_standard.df["val_f1_score"],
    balanced_data=results_analyzer_balanced.df["val_f1_score"],
)

ResultsAnalyzer.plot_statistic_function_comparison(
    df=validation_f1_score,
    figure_size=FIGURE_SIZE,
    statistic_function="f1_score",
)
validation_f1_score
# Out:
#     standard_val_f1_score  balanced_val_f1_score  Epoch
# 0                0.264323               0.228842      1
# 1                0.253336               0.279638      2
# 2                0.408774               0.362429      3
# 3                0.253074               0.348726      4
# 4                0.403147               0.415221      5
# 5                0.482561               0.385849      6
# 6                0.558780               0.465657      7
# 7                0.498942               0.412671      8
# 8                0.391123               0.388621      9
# 9                0.552966               0.483217     10
# 10               0.549704               0.475567     11
# 11               0.567285               0.537331     12
# 12               0.594461               0.490969     13
# 13               0.592017               0.532998     14
# 14               0.607470               0.573007     15
# 15               0.610760               0.489498     16
# ...

# %%
training_f1_score = ResultsAnalyzer.concat_statistic_data(
    standard_data=results_analyzer_standard.df["f1_score"],
    balanced_data=results_analyzer_balanced.df["f1_score"],
)

ResultsAnalyzer.plot_statistic_function_comparison(
    df=training_f1_score,
    figure_size=FIGURE_SIZE,
    statistic_function="f1_score",
)
training_f1_score
# Out:
#     standard_f1_score  balanced_f1_score  Epoch
# 0            0.402181           0.320174      1
# 1            0.525414           0.438702      2
# 2            0.567580           0.485548      3
# 3            0.592347           0.509893      4
# 4            0.604759           0.537071      5
# 5            0.624355           0.553983      6
# 6            0.635498           0.575477      7
# 7            0.648910           0.582579      8
# 8            0.661177           0.594297      9
# 9            0.670779           0.608921     10
# 10           0.678615           0.611324     11
# 11           0.693282           0.627305     12
# 12           0.697746           0.627203     13
# 13           0.706595           0.640749     14
# 14           0.716378           0.647232     15
# 15           0.724897           0.656213     16
# 16           0.734421           0.660104     17
# 17           0.740233           0.669891     18
# 18           0.749470           0.670134     19
# ...

# %%
validation_f1_score_angry = ResultsAnalyzer.concat_statistic_data(
    standard_data=results_analyzer_standard.df["val_f1_score_angry"],
    balanced_data=results_analyzer_balanced.df["val_f1_score_angry"],
)

ResultsAnalyzer.plot_statistic_function_comparison(
    df=validation_f1_score_angry,
    figure_size=FIGURE_SIZE,
    statistic_function="f1_score",
)

# %%
validation_f1_score_disgust = ResultsAnalyzer.concat_statistic_data(
    standard_data=results_analyzer_standard.df["val_f1_score_disgust"],
    balanced_data=results_analyzer_balanced.df["val_f1_score_disgust"],
)

ResultsAnalyzer.plot_statistic_function_comparison(
    df=validation_f1_score_disgust,
    figure_size=FIGURE_SIZE,
    statistic_function="f1_score",
)

# %%
validation_f1_score_fear = ResultsAnalyzer.concat_statistic_data(
    standard_data=results_analyzer_standard.df["val_f1_score_fear"],
    balanced_data=results_analyzer_balanced.df["val_f1_score_fear"],
)

ResultsAnalyzer.plot_statistic_function_comparison(
    df=validation_f1_score_fear,
    figure_size=FIGURE_SIZE,
    statistic_function="f1_score",
)

# %%
validation_f1_score_happy = ResultsAnalyzer.concat_statistic_data(
    standard_data=results_analyzer_standard.df["val_f1_score_happy"],
    balanced_data=results_analyzer_balanced.df["val_f1_score_happy"],
)

ResultsAnalyzer.plot_statistic_function_comparison(
    df=validation_f1_score_happy,
    figure_size=FIGURE_SIZE,
    statistic_function="f1_score",
)

# %%
validation_f1_score_neutral = ResultsAnalyzer.concat_statistic_data(
    standard_data=results_analyzer_standard.df["val_f1_score_neutral"],
    balanced_data=results_analyzer_balanced.df["val_f1_score_neutral"],
)

ResultsAnalyzer.plot_statistic_function_comparison(
    df=validation_f1_score_neutral,
    figure_size=FIGURE_SIZE,
    statistic_function="f1_score",
)

# %%
validation_f1_score_sad = ResultsAnalyzer.concat_statistic_data(
    standard_data=results_analyzer_standard.df["val_f1_score_sad"],
    balanced_data=results_analyzer_balanced.df["val_f1_score_sad"],
)

ResultsAnalyzer.plot_statistic_function_comparison(
    df=validation_f1_score_sad,
    figure_size=FIGURE_SIZE,
    statistic_function="f1_score",
)

# %%
validation_f1_score_surprise = ResultsAnalyzer.concat_statistic_data(
    standard_data=results_analyzer_standard.df["val_f1_score_surprise"],
    balanced_data=results_analyzer_balanced.df["val_f1_score_surprise"],
)

ResultsAnalyzer.plot_statistic_function_comparison(
    df=validation_f1_score_surprise,
    figure_size=FIGURE_SIZE,
    statistic_function="f1_score",
)
