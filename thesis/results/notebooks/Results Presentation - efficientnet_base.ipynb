# %% [markdown]
# ## Results Presentation - efficientnet_base

# %%
from results_analyzer import ResultsAnalyzer

# %%
RESULTS_FILE_PATH = "/Users/adamdabkowski/DataspellProjects/Thesis/thesis/results/txt/efficientnet_base_output.txt"
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
FIGURE_SIZE = (14, 5)

# %%
results_analyzer = ResultsAnalyzer(
    results_file_path=RESULTS_FILE_PATH,
    categories=CATEGORIES,
    figure_size=FIGURE_SIZE
)

# %%
results_analyzer.df
# Out:
#       loss  accuracy  precision  precision_angry  precision_disgust  \
# 0   1.7941    0.2697     0.5439           0.0800             0.1667
# 1   1.5124    0.4040     0.7252           0.3750             0.0000
# 2   1.3163    0.4934     0.7425           0.5391             0.0000
# 3   1.1888    0.5461     0.7439           0.5904             1.0000
# 4   1.1068    0.5808     0.7495           0.6319             0.6970
# 5   1.0118    0.6155     0.7560           0.6449             0.6393
# 6   0.9184    0.6571     0.7690           0.6872             0.6116
# 7   0.8144    0.6997     0.7889           0.7190             0.7756
# 8   0.7054    0.7392     0.8121           0.7599             0.7559
# 9   0.6021    0.7785     0.8341           0.7772             0.7975
# 10  0.3214    0.8896     0.9142           0.8916             0.8853
# 11  0.2151    0.9244     0.9380           0.9205             0.9237
# 12  0.1662    0.9422     0.9505           0.9314             0.9343
# 13  0.1298    0.9567     0.9622           0.9569             0.9432
# 14  0.1163    0.9622     0.9659           0.9617             0.9539
#
#     precision_fear  precision_happy  precision_neutral  precision_sad  \
# 0           0.1111           0.6231             0.1154         0.1500
# 1           0.0000           0.7550             0.5248         0.0000
# 2           0.5714           0.8179             0.6040         0.5078
# 3           0.5000           0.8478             0.6266         0.5625
# 4           0.6019           0.8616             0.6557         0.5707
# 5           0.6313           0.8797             0.6800         0.6029
# 6           0.6407           0.8952             0.7109         0.6278
# 7           0.6725           0.9102             0.7480         0.6672
# 8           0.7112           0.9225             0.7848         0.7004
# 9           0.7471           0.9361             0.8111         0.7483
# 10          0.8708           0.9709             0.9160         0.8572
# 11          0.8991           0.9809             0.9412         0.8972
# 12          0.9171           0.9854             0.9563         0.9235
# 13          0.9376           0.9864             0.9691         0.9407
# 14          0.9462           0.9883             0.9706         0.9445
#
#     precision_surprise  ...  f1_score_surprise  f1_score  val_f1_score_angry  \
# 0               0.4717  ...           0.053396  0.040439            0.000000
# 1               0.6714  ...           0.465971  0.283774            0.000000
# 2               0.7063  ...           0.595467  0.401564            0.313388
# 3               0.7342  ...           0.655783  0.473992            0.430997
# 4               0.7554  ...           0.686430  0.521108            0.352059
# 5               0.7794  ...           0.723338  0.576819            0.432612
# 6               0.8044  ...           0.759251  0.627163            0.418900
# 7               0.8317  ...           0.793142  0.682700            0.447919
# 8               0.8581  ...           0.828300  0.729165            0.348228
# 9               0.8836  ...           0.860512  0.773265            0.421487
# 10              0.9424  ...           0.930912  0.888708            0.493516
# 11              0.9653  ...           0.958857  0.924766            0.497979
# 12              0.9699  ...           0.964166  0.942635            0.475868
# 13              0.9693  ...           0.966542  0.956618            0.485566
# 14              0.9723  ...           0.969542  0.962035            0.478514
#
#     val_f1_score_disgust  val_f1_score_fear  val_f1_score_happy  \
# 0               0.000000           0.000000            0.438846
# 1               0.000000           0.000000            0.752757
# 2               0.000000           0.000000            0.786070
# 3               0.000000           0.086455            0.799472
# 4               0.000000           0.112575            0.814275
# 5               0.000000           0.317741            0.780208
# 6               0.046136           0.295285            0.822564
# 7               0.046493           0.257378            0.803927
# 8               0.132353           0.305813            0.811784
# 9               0.452429           0.354441            0.819005
# 10              0.460684           0.418174            0.829484
# 11              0.489128           0.411045            0.829876
# 12              0.467424           0.425165            0.829460
# 13              0.489373           0.418661            0.827258
# 14              0.502624           0.429628            0.822504
#
#     val_f1_score_neutral  val_f1_score_sad  val_f1_score_surprise  \
# 0               0.000000          0.000000               0.416944
# 1               0.400255          0.000000               0.622041
# 2               0.163122          0.043502               0.625256
# 3               0.321751          0.208159               0.576885
# 4               0.457864          0.246888               0.709451
# 5               0.506212          0.400500               0.623569
# 6               0.501988          0.341954               0.704670
# 7               0.504506          0.306000               0.721752
# 8               0.554337          0.481728               0.733710
# 9               0.537271          0.468690               0.724978
# 10              0.550336          0.490850               0.735935
# 11              0.559668          0.496800               0.735396
# 12              0.562592          0.493619               0.748765
# 13              0.559843          0.489950               0.739157
# 14              0.560823          0.477524               0.740743
#
#     val_f1_score
# 0       0.203963
# 1       0.422134
# 2       0.438398
# 3       0.478593
# 4       0.523462
# 5       0.535955
# 6       0.555232
# 7       0.548897
# 8       0.571954
# 9       0.590731
# 10      0.606819
# 11      0.607656
# 12      0.608088
# 13      0.605677
# 14      0.601665
#
# [15 rows x 55 columns]

# %%
results_analyzer.display_average_epoch_training_time()
# Out:
# 26 min 38 s

# %%
results_analyzer.display_total_training_time()
# Out:
# 6 h 39 min 35 s

# %%
results_analyzer.display_results()
# Out:
# loss                      1.106800
# accuracy                  0.580800
# precision                 0.749500
# precision_angry           0.631900
# precision_disgust         0.697000
# precision_fear            0.601900
# precision_happy           0.861600
# precision_neutral         0.655700
# precision_sad             0.570700
# precision_surprise        0.755400
# recall                    0.399400
# recall_angry              0.248000
# recall_disgust            0.045600
# recall_fear               0.073500
# recall_happy              0.788900
# recall_neutral            0.349700
# recall_sad                0.162900
# recall_surprise           0.629000
# val_loss                  1.144500
# val_accuracy              0.565400
# val_precision             0.725000
# val_precision_angry       0.603600
# val_precision_disgust     0.000000
# val_precision_fear        0.728600
# val_precision_happy       0.818800
# val_precision_neutral     0.598100
# val_precision_sad         0.617300
# val_precision_surprise    0.743000
# val_recall                0.409600
# val_recall_angry          0.248500
# val_recall_disgust        0.000000
# val_recall_fear           0.061000
# val_recall_happy          0.809800
# val_recall_neutral        0.370900
# val_recall_sad            0.154300
# val_recall_surprise       0.678800
# lr                        0.001000
# Epoch                     5.000000
# f1_score_angry            0.356202
# f1_score_disgust          0.085600
# f1_score_fear             0.131003
# f1_score_happy            0.823649
# f1_score_neutral          0.456133
# f1_score_sad              0.253454
# f1_score_surprise         0.686430
# f1_score                  0.521108
# val_f1_score_angry        0.352059
# val_f1_score_disgust      0.000000
# val_f1_score_fear         0.112575
# val_f1_score_happy        0.814275
# val_f1_score_neutral      0.457864
# val_f1_score_sad          0.246888
# val_f1_score_surprise     0.709451
# val_f1_score              0.523462
# Name: 4, dtype: float64

# %%
results_analyzer.plot_metric_comparison(metric="loss")

# %%
results_analyzer.plot_metric_comparison(metric="accuracy")

# %%
results_analyzer.plot_metric_comparison(metric="precision")

# %%
results_analyzer.plot_metric_comparison(metric="recall")

# %%
results_analyzer.plot_metric_comparison(metric="f1_score")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="validation")

# %%
f1_score_test = ResultsAnalyzer.calculate_f1_score(
    precision=0.7273,
    recall=0.4157,
)
print(f1_score_test)
# Out:
# 0.5290264391951006
