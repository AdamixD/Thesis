# %% [markdown]
# ## Results Presentation - mobilenet_transfer

# %%
from results_analyzer import ResultsAnalyzer

# %%
RESULTS_FILE_PATH = "/Users/adamdabkowski/DataspellProjects/Thesis/thesis/results/txt/mobilenet_transfer_output.txt"
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
FIGURE_SIZE = (14, 5)

# %%
results_analyzer = ResultsAnalyzer(
    results_file_path=RESULTS_FILE_PATH,
    categories=CATEGORIES,
    figure_size=FIGURE_SIZE
)

# %%
results_analyzer.df
# Out:
#       loss  accuracy  precision  precision_angry  precision_disgust  \
# 0   1.2127    0.5457     0.7069           0.5877             0.5833
# 1   0.9988    0.6273     0.7514           0.6847             0.6705
# 2   0.9001    0.6665     0.7659           0.7114             0.7226
# 3   0.8206    0.6961     0.7801           0.7439             0.7333
# 4   0.7341    0.7300     0.8046           0.7811             0.8049
# 5   0.6457    0.7661     0.8240           0.7930             0.8276
# 6   0.5552    0.7971     0.8423           0.8260             0.8353
# 7   0.4730    0.8266     0.8635           0.8494             0.8638
# 8   0.2148    0.9271     0.9434           0.9438             0.9492
# 9   0.1170    0.9617     0.9685           0.9747             0.9721
# 10  0.0697    0.9786     0.9816           0.9865             0.9780
# 11  0.0454    0.9866     0.9883           0.9920             0.9724
# 12  0.0359    0.9907     0.9915           0.9939             0.9762
#
#     precision_fear  precision_happy  precision_neutral  precision_sad  \
# 0           0.5707           0.8286             0.6082         0.5326
# 1           0.6567           0.8756             0.6699         0.6131
# 2           0.6731           0.8882             0.6892         0.6462
# 3           0.6843           0.9008             0.7131         0.6704
# 4           0.7074           0.9123             0.7454         0.7155
# 5           0.7552           0.9239             0.7798         0.7347
# 6           0.7665           0.9336             0.8091         0.7628
# 7           0.7874           0.9436             0.8416         0.7980
# 8           0.9108           0.9775             0.9409         0.9140
# 9           0.9396           0.9901             0.9743         0.9482
# 10          0.9659           0.9908             0.9884         0.9723
# 11          0.9750           0.9961             0.9916         0.9871
# 12          0.9871           0.9959             0.9946         0.9902
#
#     precision_surprise  ...  f1_score_surprise  f1_score  val_f1_score_angry  \
# 0               0.7327  ...           0.618701  0.489272            0.483352
# 1               0.7758  ...           0.705451  0.594642            0.317592
# 2               0.8078  ...           0.746241  0.644285            0.543105
# 3               0.8143  ...           0.768401  0.679575            0.272959
# 4               0.8390  ...           0.801877  0.720916            0.502282
# 5               0.8599  ...           0.831918  0.759637            0.463260
# 6               0.8796  ...           0.853816  0.793643            0.527191
# 7               0.8972  ...           0.875539  0.825988            0.534723
# 8               0.9481  ...           0.942011  0.927744            0.572679
# 9               0.9685  ...           0.965943  0.962918            0.558283
# 10              0.9780  ...           0.976347  0.978792            0.562519
# 11              0.9834  ...           0.982098  0.986848            0.568499
# 12              0.9845  ...           0.984700  0.990699            0.559426
#
#     val_f1_score_disgust  val_f1_score_fear  val_f1_score_happy  \
# 0               0.000000           0.170293            0.754563
# 1               0.323365           0.407671            0.680758
# 2               0.490687           0.325920            0.846943
# 3               0.472339           0.297629            0.833963
# 4               0.507775           0.276701            0.838932
# 5               0.463152           0.177530            0.845426
# 6               0.595747           0.343621            0.853075
# 7               0.511320           0.437315            0.850652
# 8               0.628286           0.501951            0.868790
# 9               0.632090           0.505707            0.862693
# 10              0.621352           0.512441            0.863700
# 11              0.622006           0.511528            0.857825
# 12              0.657309           0.496318            0.860344
#
#     val_f1_score_neutral  val_f1_score_sad  val_f1_score_surprise  \
# 0               0.222159          0.217055               0.644087
# 1               0.371775          0.171837               0.737000
# 2               0.491715          0.349763               0.746268
# 3               0.597702          0.177947               0.733415
# 4               0.603307          0.493979               0.748498
# 5               0.592253          0.499161               0.721138
# 6               0.489845          0.528061               0.743494
# 7               0.607882          0.480133               0.741520
# 8               0.593297          0.540390               0.775037
# 9               0.609743          0.545369               0.774545
# 10              0.599100          0.530850               0.772598
# 11              0.609623          0.528358               0.767880
# 12              0.611355          0.532191               0.765048
#
#     val_f1_score
# 0       0.498831
# 1       0.476227
# 2       0.590757
# 3       0.572999
# 4       0.615602
# 5       0.604893
# 6       0.616230
# 7       0.638892
# 8       0.659886
# 9       0.659725
# 10      0.656902
# 11      0.656459
# 12      0.656546
#
# [13 rows x 55 columns]

# %%
results_analyzer.display_average_epoch_training_time()
# Out:
# 13 min 23 s

# %%
results_analyzer.display_total_training_time()
# Out:
# 2 h 54 min 1 s

# %%
results_analyzer.display_results()
# Out:
# loss                      0.900100
# accuracy                  0.666500
# precision                 0.765900
# precision_angry           0.711400
# precision_disgust         0.722600
# precision_fear            0.673100
# precision_happy           0.888200
# precision_neutral         0.689200
# precision_sad             0.646200
# precision_surprise        0.807800
# recall                    0.556000
# recall_angry              0.462200
# recall_disgust            0.392100
# recall_fear               0.279900
# recall_happy              0.847100
# recall_neutral            0.522600
# recall_sad                0.397000
# recall_surprise           0.693400
# val_loss                  1.018500
# val_accuracy              0.617200
# val_precision             0.744600
# val_precision_angry       0.572600
# val_precision_disgust     0.458300
# val_precision_fear        0.641100
# val_precision_happy       0.920600
# val_precision_neutral     0.744000
# val_precision_sad         0.586400
# val_precision_surprise    0.824200
# val_recall                0.489600
# val_recall_angry          0.516500
# val_recall_disgust        0.528000
# val_recall_fear           0.218500
# val_recall_happy          0.784200
# val_recall_neutral        0.367200
# val_recall_sad            0.249200
# val_recall_surprise       0.681800
# lr                        0.001000
# Epoch                     3.000000
# f1_score_angry            0.560343
# f1_score_disgust          0.508355
# f1_score_fear             0.395384
# f1_score_happy            0.867163
# f1_score_neutral          0.594448
# f1_score_sad              0.491836
# f1_score_surprise         0.746241
# f1_score                  0.644285
# val_f1_score_angry        0.543105
# val_f1_score_disgust      0.490687
# val_f1_score_fear         0.325920
# val_f1_score_happy        0.846943
# val_f1_score_neutral      0.491715
# val_f1_score_sad          0.349763
# val_f1_score_surprise     0.746268
# val_f1_score              0.590757
# Name: 2, dtype: float64

# %%
results_analyzer.plot_metric_comparison(metric="loss")

# %%
results_analyzer.plot_metric_comparison(metric="accuracy")

# %%
results_analyzer.plot_metric_comparison(metric="precision")

# %%
results_analyzer.plot_metric_comparison(metric="recall")

# %%
results_analyzer.plot_metric_comparison(metric="f1_score")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="validation")

# %%
f1_score_test = ResultsAnalyzer.calculate_f1_score(
    precision=0.7305,
    recall=0.4845,
)
print(f1_score_test)
# Out:
# 0.5825962962962963
