# %% [markdown]
# ## Results Presentation - resnet50_base

# %%
from results_analyzer import ResultsAnalyzer

# %%
RESULTS_FILE_PATH = "/Users/adamdabkowski/DataspellProjects/Thesis/thesis/results/txt/resnet50_base_output.txt"
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
FIGURE_SIZE = (14, 5)

# %%
results_analyzer = ResultsAnalyzer(
    results_file_path=RESULTS_FILE_PATH,
    categories=CATEGORIES,
    figure_size=FIGURE_SIZE
)

# %%
results_analyzer.df
# Out:
#       loss  accuracy  precision  precision_angry  precision_disgust  \
# 0   1.8872    0.2400     0.2028           0.2581             0.1000
# 1   1.7517    0.2807     0.5678           0.0000             0.0000
# 2   1.5817    0.3778     0.6877           0.0000             0.0000
# 3   1.4188    0.4512     0.7361           0.5763             0.0000
# 4   1.3355    0.4870     0.7392           0.6170             0.4167
# 5   1.2653    0.5155     0.7403           0.5905             0.3462
# 6   1.2122    0.5344     0.7413           0.6243             0.6136
# 7   1.1678    0.5537     0.7462           0.6101             0.5584
# 8   1.1046    0.5780     0.7441           0.6435             0.6560
# 9   1.0536    0.6024     0.7501           0.6607             0.6623
# 10  0.9886    0.6234     0.7608           0.6847             0.7059
# 11  0.9278    0.6453     0.7637           0.7079             0.7320
# 12  0.8469    0.6814     0.7779           0.7123             0.8127
# 13  0.7617    0.7160     0.7995           0.7447             0.7988
# 14  0.6658    0.7530     0.8169           0.7692             0.8204
# 15  0.5554    0.7963     0.8421           0.8146             0.8660
# 16  0.2783    0.9075     0.9280           0.9293             0.9449
# 17  0.1815    0.9419     0.9520           0.9526             0.9731
# 18  0.1309    0.9587     0.9644           0.9655             0.9677
# 19  0.0986    0.9701     0.9743           0.9764             0.9544
# 20  0.0757    0.9768     0.9794           0.9767             0.9775
#
#     precision_fear  precision_happy  precision_neutral  precision_sad  \
# 0           0.2889           0.2542             0.1186         0.1304
# 1           0.0000           0.4458             0.1111         0.0000
# 2           0.0000           0.7119             0.4684         0.0000
# 3           0.0000           0.7931             0.5597         0.4286
# 4           0.0000           0.8204             0.5685         0.4500
# 5           0.0000           0.8324             0.5962         0.4835
# 6           0.3750           0.8412             0.5979         0.5284
# 7           0.4286           0.8569             0.6281         0.5403
# 8           0.4650           0.8624             0.6401         0.5566
# 9           0.5614           0.8793             0.6626         0.5726
# 10          0.6020           0.8880             0.6760         0.6145
# 11          0.5964           0.8918             0.6967         0.6272
# 12          0.6477           0.9130             0.7255         0.6368
# 13          0.6839           0.9227             0.7623         0.6862
# 14          0.7218           0.9316             0.7933         0.7081
# 15          0.7376           0.9466             0.8290         0.7481
# 16          0.8729           0.9811             0.9430         0.8638
# 17          0.9089           0.9905             0.9643         0.9122
# 18          0.9335           0.9908             0.9778         0.9355
# 19          0.9530           0.9940             0.9838         0.9578
# 20          0.9652           0.9932             0.9867         0.9692
#
#     precision_surprise  ...  f1_score_surprise  f1_score  val_f1_score_angry  \
# 0               0.1739  ...           0.002974  0.005913            0.000000
# 1               0.6047  ...           0.153946  0.022543            0.000000
# 2               0.6566  ...           0.435952  0.223875            0.000000
# 3               0.6642  ...           0.531648  0.340649            0.187971
# 4               0.6704  ...           0.572927  0.383596            0.257938
# 5               0.7036  ...           0.622087  0.426872            0.348142
# 6               0.7081  ...           0.636530  0.452947            0.185719
# 7               0.7240  ...           0.658281  0.481481            0.093998
# 8               0.7304  ...           0.677589  0.515629            0.215962
# 9               0.7464  ...           0.691083  0.550740            0.297525
# 10              0.7667  ...           0.725110  0.588326            0.409184
# 11              0.7790  ...           0.731635  0.620061            0.195150
# 12              0.7937  ...           0.757414  0.657784            0.363450
# 13              0.8132  ...           0.789689  0.703134            0.453470
# 14              0.8416  ...           0.817954  0.745276            0.450071
# 15              0.8672  ...           0.846833  0.792266            0.447180
# 16              0.9338  ...           0.926341  0.906514            0.487982
# 17              0.9508  ...           0.952397  0.942455            0.507971
# 18              0.9626  ...           0.961148  0.958767            0.481453
# 19              0.9672  ...           0.967750  0.970435            0.493436
# 20              0.9732  ...           0.972850  0.976894            0.485873
#
#     val_f1_score_disgust  val_f1_score_fear  val_f1_score_happy  \
# 0               0.000000           0.000000            0.000000
# 1               0.000000           0.000000            1.744134
# 2               0.000000           0.000000            0.400846
# 3               0.000000           0.000000            0.711458
# 4               0.000000           0.000000            0.720419
# 5               0.000000           0.000000            0.774183
# 6               0.000000           0.000000            0.779010
# 7               0.074627           0.002397            0.798572
# 8               0.075219           0.009475            0.795862
# 9               0.118519           0.054044            0.797483
# 10              0.276728           0.120746            0.814500
# 11              0.031496           0.300676            0.754207
# 12              0.046493           0.280774            0.772884
# 13              0.276709           0.357373            0.792118
# 14              0.435301           0.405638            0.795081
# 15              0.351515           0.347501            0.765104
# 16              0.505355           0.428143            0.812890
# 17              0.502842           0.424389            0.816213
# 18              0.465912           0.404847            0.811569
# 19              0.474578           0.412955            0.809332
# 20              0.477774           0.418651            0.803969
#
#     val_f1_score_neutral  val_f1_score_sad  val_f1_score_surprise  \
# 0               0.000000          0.000000               0.000000
# 1               0.000000          0.000000               0.452127
# 2               0.034343          0.000000               0.459427
# 3               0.019587          0.000000               0.589053
# 4               0.197992          0.016346               0.274970
# 5               0.302985          0.000000               0.572767
# 6               0.120647          0.392796               0.614045
# 7               0.397512          0.035866               0.649784
# 8               0.522981          0.074773               0.688559
# 9               0.555344          0.022337               0.703288
# 10              0.511615          0.321094               0.687323
# 11              0.152697          0.265483               0.620631
# 12              0.506230          0.343767               0.685215
# 13              0.286204          0.463553               0.606824
# 14              0.494435          0.424769               0.672115
# 15              0.471616          0.424056               0.479562
# 16              0.530230          0.463936               0.735942
# 17              0.531338          0.456103               0.734492
# 18              0.535722          0.478583               0.740590
# 19              0.538471          0.449450               0.736920
# 20              0.537725          0.428856               0.735120
#
#     val_f1_score
# 0       0.000000
# 1       0.126594
# 2       0.232153
# 3       0.372061
# 4       0.342649
# 5       0.433229
# 6       0.450588
# 7       0.460768
# 8       0.497836
# 9       0.510514
# 10      0.541830
# 11      0.439407
# 12      0.544551
# 13      0.534562
# 14      0.558394
# 15      0.508252
# 16      0.593618
# 17      0.593981
# 18      0.592279
# 19      0.590392
# 20      0.583715
#
# [21 rows x 55 columns]

# %%
results_analyzer.display_average_epoch_training_time()
# Out:
# 48 min 1 s

# %%
results_analyzer.display_total_training_time()
# Out:
# 16 h 48 min 28 s

# %%
results_analyzer.display_results()
# Out:
# loss                       0.988600
# accuracy                   0.623400
# precision                  0.760800
# precision_angry            0.684700
# precision_disgust          0.705900
# precision_fear             0.602000
# precision_happy            0.888000
# precision_neutral          0.676000
# precision_sad              0.614500
# precision_surprise         0.766700
# recall                     0.479600
# recall_angry               0.348700
# recall_disgust             0.285100
# recall_fear                0.105000
# recall_happy               0.840100
# recall_neutral             0.456900
# recall_sad                 0.277100
# recall_surprise            0.687800
# val_loss                   1.183800
# val_accuracy               0.557600
# val_precision              0.678700
# val_precision_angry        0.528800
# val_precision_disgust      0.666700
# val_precision_fear         0.602200
# val_precision_happy        0.814500
# val_precision_neutral      0.561600
# val_precision_sad          0.532200
# val_precision_surprise     0.765400
# val_recall                 0.450900
# val_recall_angry           0.333700
# val_recall_disgust         0.174600
# val_recall_fear            0.067100
# val_recall_happy           0.814500
# val_recall_neutral         0.469800
# val_recall_sad             0.229900
# val_recall_surprise        0.623700
# lr                         0.001000
# Epoch                     11.000000
# f1_score_angry             0.462076
# f1_score_disgust           0.406160
# f1_score_fear              0.178812
# f1_score_happy             0.863386
# f1_score_neutral           0.545263
# f1_score_sad               0.381960
# f1_score_surprise          0.725110
# f1_score                   0.588326
# val_f1_score_angry         0.409184
# val_f1_score_disgust       0.276728
# val_f1_score_fear          0.120746
# val_f1_score_happy         0.814500
# val_f1_score_neutral       0.511615
# val_f1_score_sad           0.321094
# val_f1_score_surprise      0.687323
# val_f1_score               0.541830
# Name: 10, dtype: float64

# %%
results_analyzer.plot_metric_comparison(metric="loss")

# %%
results_analyzer.plot_metric_comparison(metric="accuracy")

# %%
results_analyzer.plot_metric_comparison(metric="precision")

# %%
results_analyzer.plot_metric_comparison(metric="recall")

# %%
results_analyzer.plot_metric_comparison(metric="f1_score")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="validation")

# %%
f1_score_test = ResultsAnalyzer.calculate_f1_score(
    precision=0.6742,
    recall=0.4515,
)
print(f1_score_test)
# Out:
# 0.5408213556009595
