# %% [markdown]
# ## Results Presentation - base_base_merged_cleaned

# %%
from results_analyzer import ResultsAnalyzer

# %%
RESULTS_FILE_PATH = "/Users/adamdabkowski/DataspellProjects/Thesis/thesis/results/txt/base_base_merged_cleaned_output.txt"
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
FIGURE_SIZE = (14, 5)

# %%
results_analyzer = ResultsAnalyzer(
    results_file_path=RESULTS_FILE_PATH,
    categories=CATEGORIES,
    figure_size=FIGURE_SIZE
)

# %%
results_analyzer.df
# Out:
#       loss  accuracy  precision  precision_angry  precision_disgust  \
# 0   1.7473    0.3174     0.5317           0.2432             0.0476
# 1   1.4363    0.4463     0.6947           0.5568             0.4000
# 2   1.2800    0.5112     0.7310           0.6301             0.5818
# 3   1.1607    0.5624     0.7423           0.6509             0.7080
# 4   1.0372    0.6110     0.7582           0.7095             0.7005
# 5   0.8962    0.6694     0.7830           0.7333             0.8078
# 6   0.7504    0.7230     0.8102           0.7861             0.8685
# 7   0.5947    0.7874     0.8433           0.8105             0.8729
# 8   0.4634    0.8373     0.8755           0.8621             0.8688
# 9   0.3842    0.8652     0.8922           0.8796             0.8973
# 10  0.2395    0.9199     0.9371           0.9402             0.9418
# 11  0.1860    0.9385     0.9508           0.9515             0.9512
# 12  0.1577    0.9511     0.9600           0.9564             0.9667
# 13  0.1425    0.9548     0.9630           0.9633             0.9661
# 14  0.1240    0.9617     0.9681           0.9703             0.9654
#
#     precision_fear  precision_happy  precision_neutral  precision_sad  \
# 0           0.2500           0.5942             0.4137         0.2328
# 1           0.5074           0.7554             0.5802         0.4239
# 2           0.6338           0.8008             0.6437         0.5427
# 3           0.6683           0.8215             0.6520         0.6023
# 4           0.6884           0.8455             0.6928         0.6330
# 5           0.7260           0.8636             0.7402         0.6800
# 6           0.7670           0.8823             0.7720         0.7252
# 7           0.8100           0.9091             0.8182         0.7818
# 8           0.8424           0.9226             0.8601         0.8292
# 9           0.8561           0.9313             0.8812         0.8595
# 10          0.9302           0.9602             0.9291         0.9144
# 11          0.9370           0.9703             0.9494         0.9297
# 12          0.9489           0.9778             0.9561         0.9472
# 13          0.9515           0.9771             0.9634         0.9526
# 14          0.9608           0.9800             0.9643         0.9592
#
#     precision_surprise  ...  f1_score_surprise  f1_score  val_f1_score_angry  \
# 0               0.5980  ...           0.274578  0.168198            0.000000
# 1               0.7181  ...           0.533104  0.329655            0.021708
# 2               0.7590  ...           0.601913  0.420665            0.177193
# 3               0.7919  ...           0.657841  0.490895            0.186579
# 4               0.7979  ...           0.696966  0.563292            0.261043
# 5               0.8275  ...           0.757136  0.642325            0.347922
# 6               0.8483  ...           0.792620  0.712106            0.299398
# 7               0.8714  ...           0.837263  0.781247            0.320264
# 8               0.9083  ...           0.883279  0.834024            0.298850
# 9               0.9219  ...           0.899310  0.864198            0.395211
# 10              0.9342  ...           0.933499  0.918123            0.425686
# 11              0.9561  ...           0.946403  0.938185            0.446884
# 12              0.9618  ...           0.955762  0.950558            0.426344
# 13              0.9599  ...           0.957695  0.954424            0.425309
# 14              0.9676  ...           0.962675  0.961150            0.436397
#
#     val_f1_score_disgust  val_f1_score_fear  val_f1_score_happy  \
# 0               0.000000           0.000000            0.192211
# 1               0.000000           0.077404            0.664502
# 2               0.000000           0.018799            0.651623
# 3               0.046875           0.053154            0.683822
# 4               0.514738           0.311448            0.752656
# 5               0.392680           0.250679            0.750590
# 6               0.322566           0.211943            0.741449
# 7               0.537640           0.391849            0.759806
# 8               0.394430           0.288805            0.748716
# 9               0.583315           0.329114            0.744801
# 10              0.604154           0.418112            0.778465
# 11              0.593758           0.425551            0.779208
# 12              0.628286           0.426265            0.777931
# 13              0.612933           0.437548            0.780976
# 14              0.613719           0.419320            0.780037
#
#     val_f1_score_neutral  val_f1_score_sad  val_f1_score_surprise  \
# 0               0.046458          0.000000               0.083379
# 1               0.159137          0.043600               0.380779
# 2               0.401481          0.051305               0.500007
# 3               0.468156          0.075895               0.691231
# 4               0.435038          0.102774               0.670688
# 5               0.462015          0.326083               0.667209
# 6               0.509871          0.264778               0.693683
# 7               0.491566          0.409867               0.641717
# 8               0.515547          0.262019               0.682962
# 9               0.497033          0.408528               0.713106
# 10              0.533447          0.428809               0.729556
# 11              0.540166          0.426959               0.728448
# 12              0.539366          0.430698               0.733727
# 13              0.543942          0.436643               0.737350
# 14              0.549710          0.429112               0.733407
#
#     val_f1_score
# 0       0.069068
# 1       0.309649
# 2       0.367850
# 3       0.436577
# 4       0.486431
# 5       0.516549
# 6       0.518601
# 7       0.538479
# 8       0.517207
# 9       0.545219
# 10      0.578273
# 11      0.582113
# 12      0.579552
# 13      0.582178
# 14      0.582285
#
# [15 rows x 55 columns]

# %%
results_analyzer.display_results()
# Out:
# loss                         1.037200
# accuracy                     0.611000
# precision                    0.758200
# precision_angry              0.709500
# precision_disgust            0.700500
# precision_fear               0.688400
# precision_happy              0.845500
# precision_neutral            0.692800
# precision_sad                0.633000
# precision_surprise           0.797900
# recall                       0.448100
# recall_angry                 0.310100
# recall_disgust               0.287100
# recall_fear                  0.254200
# recall_happy                 0.735200
# recall_neutral               0.376700
# recall_sad                   0.278200
# recall_surprise              0.618700
# val_loss                     1.231500
# val_accuracy                 0.529400
# val_precision                0.724200
# val_precision_angry          0.668300
# val_precision_disgust        0.539800
# val_precision_fear           0.510900
# val_precision_happy          0.840100
# val_precision_neutral        0.656100
# val_precision_sad            0.539200
# val_precision_surprise       0.774700
# val_recall                   0.366200
# val_recall_angry             0.162200
# val_recall_disgust           0.491900
# val_recall_fear              0.224000
# val_recall_happy             0.681700
# val_recall_neutral           0.325400
# val_recall_sad               0.056800
# val_recall_surprise          0.591300
# lr                           0.001000
# epoch_time                4245.000000
# Epoch                        5.000000
# f1_score_angry               0.431573
# f1_score_disgust             0.407277
# f1_score_fear                0.371295
# f1_score_happy               0.786502
# f1_score_neutral             0.488037
# f1_score_sad                 0.386525
# f1_score_surprise            0.696966
# f1_score                     0.563292
# val_f1_score_angry           0.261043
# val_f1_score_disgust         0.514738
# val_f1_score_fear            0.311448
# val_f1_score_happy           0.752656
# val_f1_score_neutral         0.435038
# val_f1_score_sad             0.102774
# val_f1_score_surprise        0.670688
# val_f1_score                 0.486431
# Name: 4, dtype: float64

# %%
results_analyzer.display_average_epoch_training_time()
# Out:
# 70 min 57 s

# %%
results_analyzer.display_total_training_time()
# Out:
# 17 h 44 min 9 s

# %%
results_analyzer.plot_metric_comparison(metric="loss")

# %%
results_analyzer.plot_metric_comparison(metric="accuracy")

# %%
results_analyzer.plot_metric_comparison(metric="precision")

# %%
results_analyzer.plot_metric_comparison(metric="recall")

# %%
results_analyzer.plot_metric_comparison(metric="f1_score")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="validation")

# %%
f1_score_test = ResultsAnalyzer.calculate_f1_score(
    precision=0.7167,
    recall=0.3564,
)
print(f1_score_test)
# Out:
# 0.47606351691361476
