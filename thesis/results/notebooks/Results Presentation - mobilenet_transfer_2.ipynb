# %% [markdown]
# ## Results Presentation - mobilenet_transfer_2

# %%
from results_analyzer import ResultsAnalyzer

# %%
RESULTS_FILE_PATH = "/Users/adamdabkowski/DataspellProjects/Thesis/thesis/results/txt/mobilenet_transfer_2_output.txt"
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
FIGURE_SIZE = (14, 5)

# %%
results_analyzer = ResultsAnalyzer(
    results_file_path=RESULTS_FILE_PATH,
    categories=CATEGORIES,
    figure_size=FIGURE_SIZE
)

# %%
results_analyzer.df
# Out:
#       loss  accuracy  precision  precision_angry  precision_disgust  \
# 0   1.2232    0.5384     0.7146           0.6264             0.4932
# 1   1.0128    0.6221     0.7496           0.6805             0.6612
# 2   0.9093    0.6587     0.7701           0.7059             0.6988
# 3   0.8180    0.6988     0.7841           0.7354             0.7753
# 4   0.7369    0.7276     0.8016           0.7694             0.7939
# 5   0.6454    0.7619     0.8239           0.8082             0.8256
# 6   0.5603    0.7960     0.8433           0.8118             0.8598
# 7   0.4690    0.8305     0.8680           0.8484             0.8966
# 8   0.2158    0.9267     0.9405           0.9348             0.9433
# 9   0.1134    0.9626     0.9683           0.9720             0.9606
# 10  0.0686    0.9779     0.9806           0.9832             0.9719
# 11  0.0501    0.9855     0.9869           0.9893             0.9667
# 12  0.0356    0.9899     0.9905           0.9906             0.9702
#
#     precision_fear  precision_happy  precision_neutral  precision_sad  \
# 0           0.5092           0.8369             0.6023         0.5291
# 1           0.6165           0.8744             0.6629         0.6115
# 2           0.6706           0.8903             0.7001         0.6575
# 3           0.6926           0.9024             0.7181         0.6816
# 4           0.7259           0.9143             0.7460         0.6982
# 5           0.7404           0.9269             0.7841         0.7273
# 6           0.7748           0.9354             0.8164         0.7616
# 7           0.8022           0.9488             0.8512         0.7953
# 8           0.9078           0.9789             0.9461         0.9004
# 9           0.9428           0.9896             0.9769         0.9489
# 10          0.9660           0.9924             0.9901         0.9670
# 11          0.9784           0.9956             0.9899         0.9843
# 12          0.9857           0.9959             0.9953         0.9892
#
#     precision_surprise  ...  f1_score_surprise  f1_score  val_f1_score_angry  \
# 0               0.7329  ...           0.627432  0.483546            0.355346
# 1               0.7829  ...           0.709570  0.583083            0.493322
# 2               0.8022  ...           0.749331  0.639928            0.534385
# 3               0.8182  ...           0.770917  0.682303            0.542475
# 4               0.8263  ...           0.799775  0.718128            0.532831
# 5               0.8531  ...           0.826921  0.756328            0.566530
# 6               0.8755  ...           0.848970  0.792572            0.538337
# 7               0.8938  ...           0.876626  0.829843            0.551060
# 8               0.9487  ...           0.944582  0.926443            0.577051
# 9               0.9643  ...           0.964999  0.962718            0.588026
# 10              0.9770  ...           0.976600  0.978043            0.572549
# 11              0.9789  ...           0.978700  0.985498            0.579153
# 12              0.9830  ...           0.982650  0.989850            0.576371
#
#     val_f1_score_disgust  val_f1_score_fear  val_f1_score_happy  \
# 0               0.099363           0.150226            0.703553
# 1               0.000000           0.272354            0.815507
# 2               0.485979           0.282648            0.831396
# 3               0.375668           0.382956            0.833625
# 4               0.237761           0.183166            0.833163
# 5               0.580642           0.225837            0.821439
# 6               0.328946           0.258974            0.857359
# 7               0.569942           0.483877            0.851356
# 8               0.616917           0.512644            0.857051
# 9               0.649736           0.531929            0.854600
# 10              0.612259           0.539434            0.852738
# 11              0.650478           0.533920            0.856097
# 12              0.631088           0.538495            0.848172
#
#     val_f1_score_neutral  val_f1_score_sad  val_f1_score_surprise  \
# 0               0.144730          0.373073               0.673070
# 1               0.453708          0.352372               0.711292
# 2               0.585066          0.377675               0.747665
# 3               0.598215          0.169745               0.683227
# 4               0.517695          0.523650               0.754719
# 5               0.582879          0.439275               0.762728
# 6               0.569261          0.528097               0.738458
# 7               0.602541          0.478005               0.782442
# 8               0.621451          0.558389               0.800268
# 9               0.615411          0.541560               0.793801
# 10              0.618810          0.541103               0.792307
# 11              0.622649          0.553685               0.794968
# 12              0.623070          0.559245               0.785003
#
#     val_f1_score
# 0       0.452343
# 1       0.558026
# 2       0.600040
# 3       0.587158
# 4       0.597600
# 5       0.619562
# 6       0.624572
# 7       0.645006
# 8       0.670579
# 9       0.669555
# 10      0.665895
# 11      0.671831
# 12      0.668458
#
# [13 rows x 55 columns]

# %%
results_analyzer.display_average_epoch_training_time()
# Out:
# 12 min 13 s

# %%
results_analyzer.display_total_training_time()
# Out:
# 2 h 38 min 55 s

# %%
results_analyzer.display_results()
# Out:
# loss                        0.909300
# accuracy                    0.658700
# precision                   0.770100
# precision_angry             0.705900
# precision_disgust           0.698800
# precision_fear              0.670600
# precision_happy             0.890300
# precision_neutral           0.700100
# precision_sad               0.657500
# precision_surprise          0.802200
# recall                      0.547400
# recall_angry                0.436900
# recall_disgust              0.344600
# recall_fear                 0.271000
# recall_happy                0.847400
# recall_neutral              0.517000
# recall_sad                  0.378900
# recall_surprise             0.703000
# val_loss                    1.043900
# val_accuracy                0.614600
# val_precision               0.719500
# val_precision_angry         0.618000
# val_precision_disgust       0.590900
# val_precision_fear          0.555900
# val_precision_happy         0.926800
# val_precision_neutral       0.638200
# val_precision_sad           0.602700
# val_precision_surprise      0.714300
# val_recall                  0.514600
# val_recall_angry            0.470700
# val_recall_disgust          0.412700
# val_recall_fear             0.189500
# val_recall_happy            0.753800
# val_recall_neutral          0.540100
# val_recall_sad              0.275000
# val_recall_surprise         0.784300
# lr                          0.001000
# epoch_time                730.000000
# Epoch                       3.000000
# f1_score_angry              0.539740
# f1_score_disgust            0.461580
# f1_score_fear               0.386008
# f1_score_happy              0.868320
# f1_score_neutral            0.594777
# f1_score_sad                0.480754
# f1_score_surprise           0.749331
# f1_score                    0.639928
# val_f1_score_angry          0.534385
# val_f1_score_disgust        0.485979
# val_f1_score_fear           0.282648
# val_f1_score_happy          0.831396
# val_f1_score_neutral        0.585066
# val_f1_score_sad            0.377675
# val_f1_score_surprise       0.747665
# val_f1_score                0.600040
# Name: 2, dtype: float64

# %%
results_analyzer.plot_metric_comparison(metric="loss")

# %%
results_analyzer.plot_metric_comparison(metric="accuracy")

# %%
results_analyzer.plot_metric_comparison(metric="precision")

# %%
results_analyzer.plot_metric_comparison(metric="recall")

# %%
results_analyzer.plot_metric_comparison(metric="f1_score")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="validation")

# %%
f1_score_test = ResultsAnalyzer.calculate_f1_score(
    precision=0.7150,
    recall=0.5130,
)
print(f1_score_test)
# Out:
# 0.597385993485342
