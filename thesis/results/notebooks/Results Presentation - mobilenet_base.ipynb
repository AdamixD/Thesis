# %% [markdown]
# ## Results Presentation - mobilenet_base

# %%
from results_analyzer import ResultsAnalyzer

# %%
RESULTS_FILE_PATH = "/Users/adamdabkowski/DataspellProjects/Thesis/thesis/results/txt/mobilenet_base_output.txt"
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
FIGURE_SIZE = (14, 5)

# %%
results_analyzer = ResultsAnalyzer(
    results_file_path=RESULTS_FILE_PATH,
    categories=CATEGORIES,
    figure_size=FIGURE_SIZE
)

# %%
results_analyzer.df
# Out:
#       loss  accuracy  precision  precision_angry  precision_disgust  \
# 0   1.7135    0.3100     0.6402           0.1905             0.0000
# 1   1.4226    0.4522     0.7132           0.5573             0.0000
# 2   1.2690    0.5149     0.7231           0.5600             1.0000
# 3   1.1544    0.5660     0.7423           0.6457             0.6182
# 4   1.0810    0.5950     0.7415           0.6671             0.6690
# 5   1.0038    0.6262     0.7552           0.6782             0.6863
# 6   0.9341    0.6554     0.7670           0.7060             0.7672
# 7   0.8721    0.6757     0.7764           0.7294             0.7167
# 8   0.7865    0.7108     0.7944           0.7590             0.8024
# 9   0.7130    0.7384     0.8086           0.7808             0.8082
# 10  0.6214    0.7731     0.8294           0.8027             0.8260
# 11  0.3333    0.8887     0.9207           0.9217             0.9294
# 12  0.1864    0.9414     0.9545           0.9563             0.9529
# 13  0.1086    0.9691     0.9750           0.9788             0.9655
# 14  0.0743    0.9797     0.9823           0.9862             0.9665
# 15  0.0512    0.9877     0.9886           0.9920             0.9761
#
#     precision_fear  precision_happy  precision_neutral  precision_sad  \
# 0           0.2500           0.6612             0.4000         0.2500
# 1           0.0000           0.7699             0.5387         0.4706
# 2           0.4915           0.8091             0.5940         0.5117
# 3           0.6058           0.8431             0.6469         0.5677
# 4           0.6096           0.8492             0.6639         0.5912
# 5           0.6535           0.8692             0.6830         0.6070
# 6           0.6645           0.8859             0.6933         0.6352
# 7           0.6910           0.8929             0.7081         0.6510
# 8           0.7224           0.9031             0.7353         0.6760
# 9           0.7431           0.9098             0.7547         0.7105
# 10          0.7652           0.9259             0.7916         0.7484
# 11          0.8867           0.9658             0.9092         0.8741
# 12          0.9304           0.9835             0.9524         0.9322
# 13          0.9650           0.9893             0.9741         0.9645
# 14          0.9761           0.9922             0.9833         0.9770
# 15          0.9815           0.9954             0.9894         0.9892
#
#     precision_surprise  ...  f1_score_surprise  f1_score  val_f1_score_angry  \
# 0               0.5897  ...           0.164083  0.125876            0.000000
# 1               0.6730  ...           0.513639  0.336271            0.319966
# 2               0.7245  ...           0.616618  0.426257            0.058639
# 3               0.7535  ...           0.662304  0.504680            0.339295
# 4               0.7569  ...           0.681039  0.545297            0.478539
# 5               0.7955  ...           0.722398  0.590369            0.384917
# 6               0.7988  ...           0.740597  0.627266            0.473357
# 7               0.8140  ...           0.766255  0.656381            0.409582
# 8               0.8359  ...           0.792121  0.698713            0.472613
# 9               0.8464  ...           0.813790  0.729502            0.482063
# 10              0.8504  ...           0.829341  0.769115            0.447009
# 11              0.9331  ...           0.921354  0.887816            0.532396
# 12              0.9513  ...           0.951500  0.941680            0.538778
# 13              0.9698  ...           0.970000  0.969317            0.528550
# 14              0.9730  ...           0.974448  0.979894            0.518946
# 15              0.9790  ...           0.980797  0.987599            0.531089
#
#     val_f1_score_disgust  val_f1_score_fear  val_f1_score_happy  \
# 0               0.000000           0.000000            0.594401
# 1               0.000000           0.000000            0.719663
# 2               0.128997           0.011733            0.726739
# 3               0.060984           0.014246            0.788459
# 4               0.087560           0.142333            0.658659
# 5               0.380933           0.116066            0.813185
# 6               0.386369           0.378515            0.735679
# 7               0.158273           0.355729            0.810282
# 8               0.352175           0.112884            0.781303
# 9               0.476876           0.385826            0.806833
# 10              0.411429           0.435470            0.759171
# 11              0.580671           0.451242            0.839568
# 12              0.621795           0.468608            0.838548
# 13              0.584635           0.478564            0.841697
# 14              0.592556           0.472319            0.837706
# 15              0.578958           0.450285            0.832947
#
#     val_f1_score_neutral  val_f1_score_sad  val_f1_score_surprise  \
# 0               0.111505          0.000000               0.298884
# 1               0.056227          0.196165               0.278060
# 2               0.466215          0.008167               0.638935
# 3               0.322836          0.092159               0.577468
# 4               0.452112          0.203668               0.704068
# 5               0.464653          0.408203               0.712766
# 6               0.317191          0.495740               0.681968
# 7               0.548483          0.294736               0.707803
# 8               0.509281          0.416378               0.705886
# 9               0.575457          0.163202               0.730930
# 10              0.544854          0.390321               0.492840
# 11              0.599599          0.507078               0.767451
# 12              0.613067          0.484172               0.772381
# 13              0.604171          0.517005               0.769582
# 14              0.586659          0.517583               0.759384
# 15              0.604611          0.523021               0.769935
#
#     val_f1_score
# 0       0.279407
# 1       0.361256
# 2       0.427115
# 3       0.469539
# 4       0.476251
# 5       0.551853
# 6       0.532237
# 7       0.564589
# 8       0.548854
# 9       0.572702
# 10      0.530857
# 11      0.635958
# 12      0.638246
# 13      0.640519
# 14      0.631960
# 15      0.638145
#
# [16 rows x 55 columns]

# %%
results_analyzer.display_average_epoch_training_time()
# Out:
# 20 min 57 s

# %%
results_analyzer.display_total_training_time()
# Out:
# 5 h 35 min 18 s

# %%
results_analyzer.display_results()
# Out:
# loss                      1.003800
# accuracy                  0.626200
# precision                 0.755200
# precision_angry           0.678200
# precision_disgust         0.686300
# precision_fear            0.653500
# precision_happy           0.869200
# precision_neutral         0.683000
# precision_sad             0.607000
# precision_surprise        0.795500
# recall                    0.484600
# recall_angry              0.355800
# recall_disgust            0.277200
# recall_fear               0.191900
# recall_happy              0.819600
# recall_neutral            0.432000
# recall_sad                0.302500
# recall_surprise           0.661600
# val_loss                  1.122800
# val_accuracy              0.578600
# val_precision             0.712300
# val_precision_angry       0.688700
# val_precision_disgust     0.571400
# val_precision_fear        0.736100
# val_precision_happy       0.792300
# val_precision_neutral     0.654100
# val_precision_sad         0.531600
# val_precision_surprise    0.769800
# val_recall                0.450400
# val_recall_angry          0.267100
# val_recall_disgust        0.285700
# val_recall_fear           0.063000
# val_recall_happy          0.835200
# val_recall_neutral        0.360300
# val_recall_sad            0.331300
# val_recall_surprise       0.663600
# lr                        0.001000
# Epoch                     6.000000
# f1_score_angry            0.466738
# f1_score_disgust          0.394899
# f1_score_fear             0.296680
# f1_score_happy            0.843672
# f1_score_neutral          0.529248
# f1_score_sad              0.403777
# f1_score_surprise         0.722398
# f1_score                  0.590369
# val_f1_score_angry        0.384917
# val_f1_score_disgust      0.380933
# val_f1_score_fear         0.116066
# val_f1_score_happy        0.813185
# val_f1_score_neutral      0.464653
# val_f1_score_sad          0.408203
# val_f1_score_surprise     0.712766
# val_f1_score              0.551853
# Name: 5, dtype: float64

# %%
results_analyzer.plot_metric_comparison(metric="loss")

# %%
results_analyzer.plot_metric_comparison(metric="accuracy")

# %%
results_analyzer.plot_metric_comparison(metric="precision")

# %%
results_analyzer.plot_metric_comparison(metric="recall")

# %%
results_analyzer.plot_metric_comparison(metric="f1_score")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="training")

# %%
results_analyzer.plot_categories_metric_comparison(metric="f1_score", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="precision", dataset_type="validation")

# %%
results_analyzer.plot_categories_metric_comparison(metric="recall", dataset_type="validation")

# %%
f1_score_test = ResultsAnalyzer.calculate_f1_score(
    precision=0.7157,
    recall=0.4436,
)
print(f1_score_test)
# Out:
# 0.5477176227033554
