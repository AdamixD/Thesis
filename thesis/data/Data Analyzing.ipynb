# %% [markdown]
# # Data Analyzing

# %% [markdown]
# ### 0. Imports

# %%
from utils import *

# %% [markdown]
# ### 1. Paths

# %%
DATASET_BASE_TRAIN_PATH = "/Users/adamdabkowski/DataspellProjects/Praca_dyplomowa/data/train_resized"
DATASET_BASE_TEST_PATH = "/Users/adamdabkowski/DataspellProjects/Praca_dyplomowa/data/test_resized"

# %%
DATASET_OWN_PATH = "/Users/adamdabkowski/Desktop/Face Dataset/converted"

# %%
DATASET_MERGED_PATH = "/Users/adamdabkowski/DataspellProjects/Praca_dyplomowa/data/train_merged"

# %%
DATASET_MERGED_CLEANED_PATH = "/Users/adamdabkowski/DataspellProjects/Praca_dyplomowa/data/train_merged_cleaned"

# %% [markdown]
# ### 2. Categories distribution

# %%
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
# CATEGORIES = ["zły", "zniesmaczony", "przestraszony", "szczęśliwy", "neutralny", "smutny", "zaskoczony"]

# %% [markdown]
# ##### 2.1 Base dataset

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_BASE_TRAIN_PATH, DATASET_BASE_TEST_PATH],
    categories=CATEGORIES
)

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_BASE_TRAIN_PATH, DATASET_BASE_TEST_PATH],
    categories=CATEGORIES,
    design="new",
)

# %%
print_categories_distribution_table(
    dataset_paths=[DATASET_BASE_TRAIN_PATH, DATASET_BASE_TEST_PATH],
    categories=CATEGORIES
)
# Out:
# <style type="text/css">
# #T_bd513 th {
#   background-color: lightgray;
#   color: black;
#   font-weight: bold;
#   border: 1px solid gray;
# }
# #T_bd513 td {
#   border: 1px solid gray;
# }
# </style>
# <table id="T_bd513">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd513_level0_col0" class="col_heading level0 col0" >Klasa</th>
#       <th id="T_bd513_level0_col1" class="col_heading level0 col1" >Liczba próbek</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd513_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd513_row0_col0" class="data row0 col0" >angry</td>
#       <td id="T_bd513_row0_col1" class="data row0 col1" >4953</td>
#     </tr>
#     <tr>
#       <th id="T_bd513_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bd513_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_bd513_row1_col1" class="data row1 col1" >547</td>
#     </tr>
#     <tr>
#       <th id="T_bd513_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bd513_row2_col0" class="data row2 col0" >fear</td>
#       <td id="T_bd513_row2_col1" class="data row2 col1" >5121</td>
#     </tr>
#     <tr>
#       <th id="T_bd513_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bd513_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_bd513_row3_col1" class="data row3 col1" >8989</td>
#     </tr>
#     <tr>
#       <th id="T_bd513_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bd513_row4_col0" class="data row4 col0" >neutral</td>
#       <td id="T_bd513_row4_col1" class="data row4 col1" >6198</td>
#     </tr>
#     <tr>
#       <th id="T_bd513_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bd513_row5_col0" class="data row5 col0" >sad</td>
#       <td id="T_bd513_row5_col1" class="data row5 col1" >6077</td>
#     </tr>
#     <tr>
#       <th id="T_bd513_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bd513_row6_col0" class="data row6 col0" >surprise</td>
#       <td id="T_bd513_row6_col1" class="data row6 col1" >4002</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_BASE_TRAIN_PATH],
    categories=CATEGORIES
)

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_BASE_TRAIN_PATH],
    categories=CATEGORIES,
    design="new",
)

# %%
print_categories_distribution_table(
    dataset_paths=[DATASET_BASE_TRAIN_PATH],
    categories=CATEGORIES
)
# Out:
# <style type="text/css">
# #T_419fb th {
#   background-color: lightgray;
#   color: black;
#   font-weight: bold;
#   border: 1px solid gray;
# }
# #T_419fb td {
#   border: 1px solid gray;
# }
# </style>
# <table id="T_419fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_419fb_level0_col0" class="col_heading level0 col0" >Klasa</th>
#       <th id="T_419fb_level0_col1" class="col_heading level0 col1" >Liczba próbek</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_419fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_419fb_row0_col0" class="data row0 col0" >angry</td>
#       <td id="T_419fb_row0_col1" class="data row0 col1" >3995</td>
#     </tr>
#     <tr>
#       <th id="T_419fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_419fb_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_419fb_row1_col1" class="data row1 col1" >436</td>
#     </tr>
#     <tr>
#       <th id="T_419fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_419fb_row2_col0" class="data row2 col0" >fear</td>
#       <td id="T_419fb_row2_col1" class="data row2 col1" >4097</td>
#     </tr>
#     <tr>
#       <th id="T_419fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_419fb_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_419fb_row3_col1" class="data row3 col1" >7215</td>
#     </tr>
#     <tr>
#       <th id="T_419fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_419fb_row4_col0" class="data row4 col0" >neutral</td>
#       <td id="T_419fb_row4_col1" class="data row4 col1" >4965</td>
#     </tr>
#     <tr>
#       <th id="T_419fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_419fb_row5_col0" class="data row5 col0" >sad</td>
#       <td id="T_419fb_row5_col1" class="data row5 col1" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_419fb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_419fb_row6_col0" class="data row6 col0" >surprise</td>
#       <td id="T_419fb_row6_col1" class="data row6 col1" >3171</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_BASE_TEST_PATH],
    categories=CATEGORIES
)

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_BASE_TEST_PATH],
    categories=CATEGORIES,
    design="new",
)

# %%
print_categories_distribution_table(
    dataset_paths=[DATASET_BASE_TEST_PATH],
    categories=CATEGORIES
)
# Out:
# <style type="text/css">
# #T_0c337 th {
#   background-color: lightgray;
#   color: black;
#   font-weight: bold;
#   border: 1px solid gray;
# }
# #T_0c337 td {
#   border: 1px solid gray;
# }
# </style>
# <table id="T_0c337">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c337_level0_col0" class="col_heading level0 col0" >Klasa</th>
#       <th id="T_0c337_level0_col1" class="col_heading level0 col1" >Liczba próbek</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c337_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c337_row0_col0" class="data row0 col0" >angry</td>
#       <td id="T_0c337_row0_col1" class="data row0 col1" >958</td>
#     </tr>
#     <tr>
#       <th id="T_0c337_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c337_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_0c337_row1_col1" class="data row1 col1" >111</td>
#     </tr>
#     <tr>
#       <th id="T_0c337_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c337_row2_col0" class="data row2 col0" >fear</td>
#       <td id="T_0c337_row2_col1" class="data row2 col1" >1024</td>
#     </tr>
#     <tr>
#       <th id="T_0c337_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c337_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_0c337_row3_col1" class="data row3 col1" >1774</td>
#     </tr>
#     <tr>
#       <th id="T_0c337_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c337_row4_col0" class="data row4 col0" >neutral</td>
#       <td id="T_0c337_row4_col1" class="data row4 col1" >1233</td>
#     </tr>
#     <tr>
#       <th id="T_0c337_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c337_row5_col0" class="data row5 col0" >sad</td>
#       <td id="T_0c337_row5_col1" class="data row5 col1" >1247</td>
#     </tr>
#     <tr>
#       <th id="T_0c337_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c337_row6_col0" class="data row6 col0" >surprise</td>
#       <td id="T_0c337_row6_col1" class="data row6 col1" >831</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 2.2 Own dataset

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_OWN_PATH],
    categories=CATEGORIES
)

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_OWN_PATH],
    categories=CATEGORIES,
    design="new",
)

# %%
print_categories_distribution_table(
    dataset_paths=[DATASET_OWN_PATH],
    categories=CATEGORIES
)
# Out:
# <style type="text/css">
# #T_08468 th {
#   background-color: lightgray;
#   color: black;
#   font-weight: bold;
#   border: 1px solid gray;
# }
# #T_08468 td {
#   border: 1px solid gray;
# }
# </style>
# <table id="T_08468">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08468_level0_col0" class="col_heading level0 col0" >Klasa</th>
#       <th id="T_08468_level0_col1" class="col_heading level0 col1" >Liczba próbek</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08468_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08468_row0_col0" class="data row0 col0" >angry</td>
#       <td id="T_08468_row0_col1" class="data row0 col1" >202</td>
#     </tr>
#     <tr>
#       <th id="T_08468_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_08468_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_08468_row1_col1" class="data row1 col1" >207</td>
#     </tr>
#     <tr>
#       <th id="T_08468_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_08468_row2_col0" class="data row2 col0" >fear</td>
#       <td id="T_08468_row2_col1" class="data row2 col1" >207</td>
#     </tr>
#     <tr>
#       <th id="T_08468_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_08468_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_08468_row3_col1" class="data row3 col1" >229</td>
#     </tr>
#     <tr>
#       <th id="T_08468_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_08468_row4_col0" class="data row4 col0" >neutral</td>
#       <td id="T_08468_row4_col1" class="data row4 col1" >200</td>
#     </tr>
#     <tr>
#       <th id="T_08468_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_08468_row5_col0" class="data row5 col0" >sad</td>
#       <td id="T_08468_row5_col1" class="data row5 col1" >201</td>
#     </tr>
#     <tr>
#       <th id="T_08468_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_08468_row6_col0" class="data row6 col0" >surprise</td>
#       <td id="T_08468_row6_col1" class="data row6 col1" >207</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 2.3 Merged dataset

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_MERGED_PATH],
    categories=CATEGORIES
)

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_MERGED_PATH],
    categories=CATEGORIES,
    design="new",
)

# %%
print_categories_distribution_table(
    dataset_paths=[DATASET_MERGED_PATH],
    categories=CATEGORIES
)
# Out:
# <style type="text/css">
# #T_b95c6 th {
#   background-color: lightgray;
#   color: black;
#   font-weight: bold;
#   border: 1px solid gray;
# }
# #T_b95c6 td {
#   border: 1px solid gray;
# }
# </style>
# <table id="T_b95c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b95c6_level0_col0" class="col_heading level0 col0" >Klasa</th>
#       <th id="T_b95c6_level0_col1" class="col_heading level0 col1" >Liczba próbek</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b95c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b95c6_row0_col0" class="data row0 col0" >angry</td>
#       <td id="T_b95c6_row0_col1" class="data row0 col1" >4197</td>
#     </tr>
#     <tr>
#       <th id="T_b95c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b95c6_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_b95c6_row1_col1" class="data row1 col1" >643</td>
#     </tr>
#     <tr>
#       <th id="T_b95c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b95c6_row2_col0" class="data row2 col0" >fear</td>
#       <td id="T_b95c6_row2_col1" class="data row2 col1" >4304</td>
#     </tr>
#     <tr>
#       <th id="T_b95c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b95c6_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_b95c6_row3_col1" class="data row3 col1" >7444</td>
#     </tr>
#     <tr>
#       <th id="T_b95c6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b95c6_row4_col0" class="data row4 col0" >neutral</td>
#       <td id="T_b95c6_row4_col1" class="data row4 col1" >5165</td>
#     </tr>
#     <tr>
#       <th id="T_b95c6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b95c6_row5_col0" class="data row5 col0" >sad</td>
#       <td id="T_b95c6_row5_col1" class="data row5 col1" >5031</td>
#     </tr>
#     <tr>
#       <th id="T_b95c6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b95c6_row6_col0" class="data row6 col0" >surprise</td>
#       <td id="T_b95c6_row6_col1" class="data row6 col1" >3378</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### 2.4 Merged dataset (cleaned)

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_MERGED_CLEANED_PATH],
    categories=CATEGORIES
)

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_MERGED_CLEANED_PATH],
    categories=CATEGORIES,
    design="new",
)

# %%
print_categories_distribution_table(
    dataset_paths=[DATASET_MERGED_CLEANED_PATH],
    categories=CATEGORIES,
)
# Out:
# <style type="text/css">
# #T_2564d th {
#   background-color: lightgray;
#   color: black;
#   font-weight: bold;
#   border: 1px solid gray;
# }
# #T_2564d td {
#   border: 1px solid gray;
# }
# </style>
# <table id="T_2564d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2564d_level0_col0" class="col_heading level0 col0" >Klasa</th>
#       <th id="T_2564d_level0_col1" class="col_heading level0 col1" >Liczba próbek</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2564d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2564d_row0_col0" class="data row0 col0" >angry</td>
#       <td id="T_2564d_row0_col1" class="data row0 col1" >4121</td>
#     </tr>
#     <tr>
#       <th id="T_2564d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2564d_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_2564d_row1_col1" class="data row1 col1" >631</td>
#     </tr>
#     <tr>
#       <th id="T_2564d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2564d_row2_col0" class="data row2 col0" >fear</td>
#       <td id="T_2564d_row2_col1" class="data row2 col1" >4218</td>
#     </tr>
#     <tr>
#       <th id="T_2564d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2564d_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_2564d_row3_col1" class="data row3 col1" >7361</td>
#     </tr>
#     <tr>
#       <th id="T_2564d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2564d_row4_col0" class="data row4 col0" >neutral</td>
#       <td id="T_2564d_row4_col1" class="data row4 col1" >5084</td>
#     </tr>
#     <tr>
#       <th id="T_2564d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2564d_row5_col0" class="data row5 col0" >sad</td>
#       <td id="T_2564d_row5_col1" class="data row5 col1" >4873</td>
#     </tr>
#     <tr>
#       <th id="T_2564d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2564d_row6_col0" class="data row6 col0" >surprise</td>
#       <td id="T_2564d_row6_col1" class="data row6 col1" >3320</td>
#     </tr>
#   </tbody>
# </table>
