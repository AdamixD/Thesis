# %% [markdown]
# # Data Analyzing

# %% [markdown]
# ### 0. Imports

# %%
from utils import *

# %% [markdown]
# ### 1. Paths

# %%
DATASET_BASE_TRAIN_PATH = "/Users/adamdabkowski/DataspellProjects/Praca_dyplomowa/data/train_resized"
DATASET_BASE_TEST_PATH = "/Users/adamdabkowski/DataspellProjects/Praca_dyplomowa/data/test_resized"

# %%
DATASET_OWN_PATH = "/Users/adamdabkowski/Desktop/Face Dataset/converted"

# %% [markdown]
# ### 2. Categories distribution

# %%
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

# %% [markdown]
# ##### 2.1 Base dataset

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_BASE_TRAIN_PATH, DATASET_BASE_TEST_PATH],
    categories=CATEGORIES
)

# %%
print_categories_distribution_table(
    dataset_paths=[DATASET_BASE_TRAIN_PATH, DATASET_BASE_TEST_PATH],
    categories=CATEGORIES
)
# Out:
# <style type="text/css">
# #T_aa99b_ th {
#   background-color: lightgray;
#   color: black;
#   font-weight: bold;
#   border: 1px solid gray;
# }
# #T_aa99b_ td {
#   border: 1px solid gray;
# }
# </style>
# <table id="T_aa99b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Klasa</th>
#       <th class="col_heading level0 col1" >Liczba próbek</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa99b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa99b_row0_col0" class="data row0 col0" >angry</td>
#       <td id="T_aa99b_row0_col1" class="data row0 col1" >4953</td>
#     </tr>
#     <tr>
#       <th id="T_aa99b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aa99b_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_aa99b_row1_col1" class="data row1 col1" >547</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ##### 2.2 Own dataset

# %%
plot_categories_distribution(
    dataset_paths=[DATASET_OWN_PATH],
    categories=CATEGORIES
)

# %%
print_categories_distribution_table(
    dataset_paths=[DATASET_OWN_PATH],
    categories=CATEGORIES
)
# Out:
# <style type="text/css">
# #T_73924_ th {
#   background-color: lightgray;
#   color: black;
#   font-weight: bold;
#   border: 1px solid gray;
# }
# #T_73924_ td {
#   border: 1px solid gray;
# }
# </style>
# <table id="T_73924_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Klasa</th>
#       <th class="col_heading level0 col1" >Liczba próbek</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73924_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73924_row0_col0" class="data row0 col0" >angry</td>
#       <td id="T_73924_row0_col1" class="data row0 col1" >202</td>
#     </tr>
#     <tr>
#       <th id="T_73924_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73924_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_73924_row1_col1" class="data row1 col1" >207</td>
#     </tr>
#     <tr>
# ...
