# %% [markdown]
# # Model Training (model merged data 1)

# %% [markdown]
# ### 0. Imports

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import (
    Dense,
    Dropout,
    Flatten,
    Conv2D,
    BatchNormalization,
    Activation,
    MaxPooling2D
)
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### 1. Paths

# %%
# DATASET_BASE_TRAIN_PATH = "/Users/adamdabkowski/DataspellProjects/Praca_dyplomowa/data/train_resized"
# DATASET_BASE_TRAIN_PATH = "/Users/adamd/DataspellProjects/Facial Expressions Recognition/data/train_resized"
DATASET_BASE_TRAIN_PATH = "/Users/adamd/DataspellProjects/Facial Expressions Recognition/data/train_merged"

# DATASET_BASE_TRAIN_PATH = "../new_data"

# DATASET_BASE_TEST_PATH = "/Users/adamdabkowski/DataspellProjects/Praca_dyplomowa/data/test_resized"
DATASET_BASE_TEST_PATH = "/Users/adamd/DataspellProjects/Facial Expressions Recognition/data/test_resized"

# %% [markdown]
# ### 2. Data preprocessing

# %%
batch_size  = 32
img_size = 128

datagen_train  = ImageDataGenerator()
datagen_val = ImageDataGenerator()

train_set = datagen_train.flow_from_directory(
    DATASET_BASE_TRAIN_PATH,
    target_size = (img_size,img_size),
    color_mode = "grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
)

test_set = datagen_val.flow_from_directory(
    DATASET_BASE_TEST_PATH,
    target_size=(img_size,img_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 30156 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### 5. Model creating

# %%
CATEGORIES = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint(
    filepath="./model_merged_data_1.h5",
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    mode='min'
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

reduce_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    verbose=1,
    min_delta=0.0001,
)

callbacks_list = [early_stopping, checkpoint, reduce_learning_rate]

# %%
from keras.optimizers import Adam

n_classes = len(CATEGORIES)

model = Sequential()

model.add(Conv2D(64,(3,3),padding = 'same',input_shape = (img_size,img_size,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

model.add(Conv2D(512,(3,3),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(n_classes, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      640
#
#  batch_normalization (BatchN  (None, 128, 128, 64)     256
#  ormalization)
#
#  activation (Activation)     (None, 128, 128, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 128)       204928
#
#  batch_normalization_1 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 64, 64, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 32, 32, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 32, 32, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 512)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 512)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 512)       2359808
#
#  batch_normalization_3 (Batc  (None, 16, 16, 512)      2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 512)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 256)               8388864
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 11,687,687
# Trainable params: 11,683,719
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_1_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### 6. Model training

# %%
epochs = 50

# %%
history = model.fit_generator(
    generator=train_set,
    steps_per_epoch=train_set.n//train_set.batch_size,
    epochs=epochs,
    validation_data = test_set,
    validation_steps = test_set.n//test_set.batch_size,
    callbacks=callbacks_list,
)
# Out:
# C:\Users\adamd\AppData\Local\Temp\ipykernel_17572\2934536250.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/50
# 942/942 [==============================] - ETA: 0s - loss: 1.7351 - accuracy: 0.3345
# Epoch 1: val_loss improved from inf to 1.93052, saving model to .\model_merged_data_1.h5
# 942/942 [==============================] - 1534s 2s/step - loss: 1.7351 - accuracy: 0.3345 - val_loss: 1.9305 - val_accuracy: 0.2164 - lr: 0.0010
# Epoch 2/50
# 942/942 [==============================] - ETA: 0s - loss: 1.3793 - accuracy: 0.4703
# Epoch 2: val_loss improved from 1.93052 to 1.30094, saving model to .\model_merged_data_1.h5
# 942/942 [==============================] - 1470s 2s/step - loss: 1.3793 - accuracy: 0.4703 - val_loss: 1.3009 - val_accuracy: 0.4895 - lr: 0.0010
# Epoch 3/50
# 942/942 [==============================] - ETA: 0s - loss: 1.2366 - accuracy: 0.5282
# Epoch 3: val_loss improved from 1.30094 to 1.20126, saving model to .\model_merged_data_1.h5
# 942/942 [==============================] - 1459s 2s/step - loss: 1.2366 - accuracy: 0.5282 - val_loss: 1.2013 - val_accuracy: 0.5391 - lr: 0.0010
# Epoch 4/50
# 942/942 [==============================] - ETA: 0s - loss: 1.1419 - accuracy: 0.5684
# Epoch 4: val_loss did not improve from 1.20126
# 942/942 [==============================] - 1471s 2s/step - loss: 1.1419 - accuracy: 0.5684 - val_loss: 1.2171 - val_accuracy: 0.5388 - lr: 0.0010
# Epoch 5/50
# 942/942 [==============================] - ETA: 0s - loss: 1.0525 - accuracy: 0.6056
# Epoch 5: val_loss did not improve from 1.20126
# 942/942 [==============================] - 1477s 2s/step - loss: 1.0525 - accuracy: 0.6056 - val_loss: 1.2090 - val_accuracy: 0.5453 - lr: 0.0010
# Epoch 6/50
# 942/942 [==============================] - ETA: 0s - loss: 0.9556 - accuracy: 0.6434
# Epoch 6: val_loss improved from 1.20126 to 1.08741, saving model to .\model_merged_data_1.h5
# 942/942 [==============================] - 1476s 2s/step - loss: 0.9556 - accuracy: 0.6434 - val_loss: 1.0874 - val_accuracy: 0.5896 - lr: 0.0010
# Epoch 7/50
# 942/942 [==============================] - ETA: 0s - loss: 0.8532 - accuracy: 0.6796
# Epoch 7: val_loss did not improve from 1.08741
# 942/942 [==============================] - 1463s 2s/step - loss: 0.8532 - accuracy: 0.6796 - val_loss: 1.1433 - val_accuracy: 0.5811 - lr: 0.0010
# Epoch 8/50
# 942/942 [==============================] - ETA: 0s - loss: 0.7524 - accuracy: 0.7207
# Epoch 8: val_loss did not improve from 1.08741
# 942/942 [==============================] - 1465s 2s/step - loss: 0.7524 - accuracy: 0.7207 - val_loss: 1.1806 - val_accuracy: 0.5891 - lr: 0.0010
# Epoch 9/50
# 942/942 [==============================] - ETA: 0s - loss: 0.6425 - accuracy: 0.7635
# Epoch 9: val_loss did not improve from 1.08741
# 942/942 [==============================] - 1464s 2s/step - loss: 0.6425 - accuracy: 0.7635 - val_loss: 1.1723 - val_accuracy: 0.5940 - lr: 0.0010
# Epoch 10/50
# 942/942 [==============================] - ETA: 0s - loss: 0.5484 - accuracy: 0.7984
# Epoch 10: val_loss did not improve from 1.08741
# 942/942 [==============================] - 1454s 2s/step - loss: 0.5484 - accuracy: 0.7984 - val_loss: 1.2147 - val_accuracy: 0.6011 - lr: 0.0010
# Epoch 11/50
# 942/942 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.8283
# Epoch 11: val_loss did not improve from 1.08741
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 942/942 [==============================] - 1460s 2s/step - loss: 0.4656 - accuracy: 0.8283 - val_loss: 1.3336 - val_accuracy: 0.5917 - lr: 0.0010
# Epoch 12/50
# 942/942 [==============================] - ETA: 0s - loss: 0.2971 - accuracy: 0.8948
# Epoch 12: val_loss did not improve from 1.08741
# 942/942 [==============================] - 1463s 2s/step - loss: 0.2971 - accuracy: 0.8948 - val_loss: 1.3270 - val_accuracy: 0.6317 - lr: 2.0000e-04
# Epoch 13/50
# 942/942 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9161
# Epoch 13: val_loss did not improve from 1.08741
# 942/942 [==============================] - 1461s 2s/step - loss: 0.2394 - accuracy: 0.9161 - val_loss: 1.3802 - val_accuracy: 0.6311 - lr: 2.0000e-04
# Epoch 14/50
# 942/942 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9282
# Epoch 14: val_loss did not improve from 1.08741
# 942/942 [==============================] - 1454s 2s/step - loss: 0.2039 - accuracy: 0.9282 - val_loss: 1.4552 - val_accuracy: 0.6311 - lr: 2.0000e-04
# Epoch 15/50
# 942/942 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9355
# Epoch 15: val_loss did not improve from 1.08741
# 942/942 [==============================] - 1465s 2s/step - loss: 0.1883 - accuracy: 0.9355 - val_loss: 1.4849 - val_accuracy: 0.6299 - lr: 2.0000e-04
# Epoch 16/50
# 942/942 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9431Restoring model weights from the end of the best epoch: 6.
#
# Epoch 16: val_loss did not improve from 1.08741
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 942/942 [==============================] - 1467s 2s/step - loss: 0.1643 - accuracy: 0.9431 - val_loss: 1.5576 - val_accuracy: 0.6352 - lr: 2.0000e-04
# Epoch 16: early stopping

# %% [markdown]
# ### 7. Results

# %% [markdown]
# **7.1 Loss**

# %%
plt.figure(figsize=(20,10))
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 plt.ylabel('Loss', fontsize=16)
#       3 plt.xlabel('Epoch', fontsize=16)
# ----> 4 plt.plot(history.history['loss'], label='Training Loss')
#       5 plt.plot(history.history['val_loss'], label='Validation Loss')
#       6 plt.legend(loc='upper right')
#
# NameError: name 'history' is not defined

# %% [markdown]
# **7.2 Accuracy**

# %%
plt.figure(figsize=(20,10))
plt.ylabel('Accuracy', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.figure(figsize=(20,10))
#       2 plt.ylabel('Accuracy', fontsize=16)
#       3 plt.xlabel('Epoch', fontsize=16)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
